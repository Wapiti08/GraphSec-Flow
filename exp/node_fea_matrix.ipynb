# %%
from pathlib import Path
import pandas as pd

# %%
fea_matrix = Path.cwd().parent.joinpath("data", "fea_matrix.csv")

# %%
fea_matrix_df = pd.read_csv(fea_matrix)

# %%
fea_matrix_df.head()
# Out:
#    id  freshness_missrelease  freshness_outdays  popularity     speed  \
# 0  n0                      0           0.000000           0  0.014109
# 1  n1                      0           0.000000           0  0.706280
# 2  n2                      0           0.000000           0  0.038056
# 3  n3                    643        1098.438576           0  0.000000
# 4  n4                     62        1632.094514           0  0.000000
#
#    severity  outdegree  degree
# 0         0         16      32
# 1         0       1046    3600
# 2         0         65      65
# 3         0         15      16
# 4         0          0       1

# %%
fea_matrix_df['popularity'].value_counts()
# Out:
# popularity
# 0        13807866
# 1          573286
# 2          221985
# 3          122276
# 4           81251
#            ...
# 15785           1
# 13335           1
# 4117            1
# 1101            1
# 794             1
# Name: count, Length: 2598, dtype: int64

# %%
fea_matrix_df['freshness_missrelease'].value_counts()
# Out:
# freshness_missrelease
# 0       1295389
# 1        493813
# 2        418728
# 3        368418
# 4        329427
#          ...
# 4511          1
# 4075          1
# 3672          1
# 3684          1
# 4494          1
# Name: count, Length: 4639, dtype: int64

# %%
fea_matrix_df['freshness_outdays'].value_counts()
# Out:
# freshness_outdays
# 0.000000       1295389
# 0.000012           914
# 0.000023           388
# 0.000035           269
# 360.289676         267
#                 ...
# 456.782512           1
# 1126.089757          1
# 670.958125           1
# 1.219514             1
# 117.010660           1
# Name: count, Length: 10322376, dtype: int64

# %%
fea_matrix_df['severity'].value_counts()
# Out:
# severity
# 0      15039833
# 3         22289
# 2         14933
# 4         13721
# 5          3739
#          ...
# 197           1
# 181           1
# 214           1
# 210           1
# 71            1
# Name: count, Length: 134, dtype: int64

# %%
fea_matrix_df['outdegree'].value_counts()
# Out:
# outdegree
# 0      668636
# 4        5049
# 3        4041
# 6        3683
# 1        3403
#         ...
# 201         1
# 260         1
# 441         1
# 239         1
# 370         1
# Name: count, Length: 247, dtype: int64
