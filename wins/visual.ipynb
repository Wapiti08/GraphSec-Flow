# %%
import matplotlib.pyplot as plt

# %%
ts = None
centrality_series = None
peaks = None
wins = None


plt.plot(ts, centrality_series, label="Centrality")
plt.scatter([ts[p] for p in peaks], [centrality_series[p] for p in peaks], color="red", label="Peaks")

for start, end in wins:
    plt.axvspan(start, end, color="yellow", alpha=0.3)

plt.legend()
plt.show()
